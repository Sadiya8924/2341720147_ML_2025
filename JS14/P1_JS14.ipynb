# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
from google.colab import drive
drive.mount('/content/drive')

train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)
training_set = train_datagen.flow_from_directory('/content/drive/MyDrive/ml/dataset/training_set',
                                                 target_size = (64, 64),
                                                 batch_size = 32,
                                                 class_mode = 'binary')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Found 8000 images belonging to 2 classes.

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)
test_set = test_datagen.flow_from_directory('/content/drive/MyDrive/ml/dataset/test_set',
                                            target_size = (64, 64),
                                            batch_size = 32,
                                            class_mode = 'binary')
# Out:
# Found 2000 images belonging to 2 classes.

# %%
cnn = tf.keras.models.Sequential()

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu', input_shape=[64, 64, 3]))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %%
cnn.add(tf.keras.layers.Flatten())

# %%
cnn.add(tf.keras.layers.Dense(units=128, activation='relu'))

# %%
cnn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# %%
cnn.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
cnn.fit(x = training_set, validation_data = test_set, epochs = 25)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1563s 6s/step - accuracy: 0.5848 - loss: 0.6720 - val_accuracy: 0.6750 - val_loss: 0.6097
# Epoch 2/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 98s 392ms/step - accuracy: 0.6950 - loss: 0.5801 - val_accuracy: 0.7295 - val_loss: 0.5454
# Epoch 3/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 95s 379ms/step - accuracy: 0.7426 - loss: 0.5210 - val_accuracy: 0.7605 - val_loss: 0.5053
# Epoch 4/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 95s 378ms/step - accuracy: 0.7463 - loss: 0.5017 - val_accuracy: 0.7585 - val_loss: 0.4936
# Epoch 5/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 93s 373ms/step - accuracy: 0.7738 - loss: 0.4798 - val_accuracy: 0.7645 - val_loss: 0.4989
# Epoch 6/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 94s 377ms/step - accuracy: 0.7819 - loss: 0.4596 - val_accuracy: 0.7430 - val_loss: 0.5216
# Epoch 7/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 94s 377ms/step - accuracy: 0.7825 - loss: 0.4563 - val_accuracy: 0.7780 - val_loss: 0.4604
# Epoch 8/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 93s 371ms/step - accuracy: 0.7922 - loss: 0.4334 - val_accuracy: 0.7660 - val_loss: 0.4999
# Epoch 9/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 95s 380ms/step - accuracy: 0.8066 - loss: 0.4203 - val_accuracy: 0.7885 - val_loss: 0.4677
# Epoch 10/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 94s 377ms/step - accuracy: 0.7985 - loss: 0.4195 - val_accuracy: 0.7700 - val_loss: 0.4971
# Epoch 11/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 143s 379ms/step - accuracy: 0.8204 - loss: 0.3941 - val_accuracy: 0.7965 - val_loss: 0.4773
# Epoch 12/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 96s 382ms/step - accuracy: 0.8245 - loss: 0.3878 - val_accuracy: 0.7970 - val_loss: 0.4827
# Epoch 13/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 96s 386ms/step - accuracy: 0.8284 - loss: 0.3775 - val_accuracy: 0.8120 - val_loss: 0.4465
# Epoch 14/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 93s 373ms/step - accuracy: 0.8437 - loss: 0.3541 - val_accuracy: 0.7925 - val_loss: 0.4554
# Epoch 15/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 95s 380ms/step - accuracy: 0.8453 - loss: 0.3467 - val_accuracy: 0.8055 - val_loss: 0.4652
# Epoch 16/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 95s 380ms/step - accuracy: 0.8493 - loss: 0.3391 - val_accuracy: 0.8110 - val_loss: 0.4409
# Epoch 17/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 94s 376ms/step - accuracy: 0.8531 - loss: 0.3256 - val_accuracy: 0.8110 - val_loss: 0.4757
# Epoch 18/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 142s 376ms/step - accuracy: 0.8506 - loss: 0.3331 - val_accuracy: 0.7995 - val_loss: 0.5050
# Epoch 19/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 92s 368ms/step - accuracy: 0.8684 - loss: 0.3029 - val_accuracy: 0.8065 - val_loss: 0.4654
# Epoch 20/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 93s 371ms/step - accuracy: 0.8759 - loss: 0.2897 - val_accuracy: 0.8020 - val_loss: 0.4860
# Epoch 21/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 101s 404ms/step - accuracy: 0.8782 - loss: 0.2899 - val_accuracy: 0.8060 - val_loss: 0.4891
# Epoch 22/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 92s 370ms/step - accuracy: 0.8754 - loss: 0.2878 - val_accuracy: 0.8080 - val_loss: 0.4591
# Epoch 23/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 91s 364ms/step - accuracy: 0.8858 - loss: 0.2571 - val_accuracy: 0.8010 - val_loss: 0.5014
# Epoch 24/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 92s 369ms/step - accuracy: 0.8962 - loss: 0.2444 - val_accuracy: 0.8050 - val_loss: 0.5148
# Epoch 25/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 90s 360ms/step - accuracy: 0.9068 - loss: 0.2297 - val_accuracy: 0.8195 - val_loss: 0.5197

# %%
import numpy as np
from keras.preprocessing import image
test_image = image.load_img('/content/drive/MyDrive/ml/dataset/single_prediction/cat_or_dog_1.jpg', target_size = (64, 64))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = cnn.predict(test_image)
training_set.class_indices
if result[0][0] == 1:
  prediction = 'dog'
else:
  prediction = 'cat'
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
